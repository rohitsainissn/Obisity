# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train.csv')
df
# Out:
#           id  Gender        Age    Height      Weight  \
# 0          0    Male  24.443011  1.699998   81.669950
# 1          1  Female  18.000000  1.560000   57.000000
# 2          2  Female  18.000000  1.711460   50.165754
# 3          3  Female  20.952737  1.710730  131.274851
# 4          4    Male  31.641081  1.914186   93.798055
# ...      ...     ...        ...       ...         ...
# 20753  20753    Male  25.137087  1.766626  114.187096
# 20754  20754    Male  18.000000  1.710000   50.000000
# 20755  20755    Male  20.101026  1.819557  105.580491
# 20756  20756    Male  33.852953  1.700000   83.520113
# 20757  20757    Male  26.680376  1.816547  118.134898
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.000000  2.983297   Sometimes
# 1                                yes  yes  2.000000  3.000000  Frequently
# 2                                yes  yes  1.880534  1.411685   Sometimes
# ...

# %%
X_test = pd.read_csv('test.csv')
X_test_id = X_test.id
X_test_id
# Out:
# 0        20758
# 1        20759
# 2        20760
# 3        20761
# 4        20762
#          ...
# 13835    34593
# 13836    34594
# 13837    34595
# 13838    34596
# 13839    34597
# Name: id, Length: 13840, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Gender                          20758 non-null  object
#  2   Age                             20758 non-null  float64
#  3   Height                          20758 non-null  float64
#  4   Weight                          20758 non-null  float64
#  5   family_history_with_overweight  20758 non-null  object
#  6   FAVC                            20758 non-null  object
#  7   FCVC                            20758 non-null  float64
#  8   NCP                             20758 non-null  float64
#  9   CAEC                            20758 non-null  object
#  10  SMOKE                           20758 non-null  object
#  11  CH2O                            20758 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#                  id  Gender           Age        Height        Weight  \
# count   20758.00000   20758  20758.000000  20758.000000  20758.000000
# unique          NaN       2           NaN           NaN           NaN
# top             NaN  Female           NaN           NaN           NaN
# freq            NaN   10422           NaN           NaN           NaN
# mean    10378.50000     NaN     23.841804      1.700245     87.887768
# std      5992.46278     NaN      5.688072      0.087312     26.379443
# min         0.00000     NaN     14.000000      1.450000     39.000000
# 25%      5189.25000     NaN     20.000000      1.631856     66.000000
# 50%     10378.50000     NaN     22.815416      1.700000     84.064875
# 75%     15567.75000     NaN     26.000000      1.762887    111.600553
# max     20757.00000     NaN     61.000000      1.975663    165.057269
#
#        family_history_with_overweight   FAVC          FCVC           NCP  \
# ...

# %%
df=df.drop('id',axis=1)
X_test=X_test.drop('id',axis=1)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
X_test.isnull().sum().sum()
# Out:
# 0

# %%
numerical_columns = df.select_dtypes(include=['number']).columns.tolist()
categorical_columns = df.select_dtypes(include=['object', 'bool']).columns.tolist()

# %%
categorical_columns
# Out:
# ['Gender',
#  'family_history_with_overweight',
#  'FAVC',
#  'CAEC',
#  'SMOKE',
#  'SCC',
#  'CALC',
#  'MTRANS',
#  'NObeyesdad']

# %%
df.NObeyesdad.value_counts()
# Out:
# Obesity_Type_III       4046
# Obesity_Type_II        3248
# Normal_Weight          3082
# Obesity_Type_I         2910
# Insufficient_Weight    2523
# Overweight_Level_II    2522
# Overweight_Level_I     2427
# Name: NObeyesdad, dtype: int64

# %%
categories = [
    'Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 
    'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II', 
    'Obesity_Type_III'
]

# Encode the 'NObeyesdad' feature
encoder = OrdinalEncoder(categories=[categories])
df['NObeyesdad_encoded'] = encoder.fit_transform(df[['NObeyesdad']])

# %%
df = df.drop('NObeyesdad',axis =1)

# %%
df.CALC.value_counts()
# Out:
# Sometimes     15066
# no             5163
# Frequently      529
# Name: CALC, dtype: int64

# %%
df.replace('Motorbike', 'Bike', inplace=True)

# %%
X_test.replace('Motorbike', 'Bike', inplace=True)

# %%
categories = [
    'no', 'Sometimes','Frequently','Always'
]

# Encode the 'NObeyesdad' feature
encoder = OrdinalEncoder(categories=[categories])
df['CALC_encoded'] = encoder.fit_transform(df[['CALC']])

# %%
X_test['CALC_encoded'] = encoder.transform(X_test[['CALC']])

# %%
categories = [
    'no', 'Sometimes','Frequently', 'Always'
]

# Encode the 'NObeyesdad' feature
encoder = OrdinalEncoder(categories=[categories])
df['CAEC_encoded'] = encoder.fit_transform(df[['CAEC']])

# %%
X_test['CAEC_encoded'] = encoder.transform(X_test[['CAEC']])

# %%
df = df.drop(['CAEC','CALC'], axis =1)

# %%
X_test= X_test.drop(['CAEC','CALC'], axis =1)

# %%
cardianl_columns = ['Gender',
 'family_history_with_overweight',
 'FAVC',
 'SMOKE',
 'SCC',
 'MTRANS',
]
df = pd.get_dummies(df, columns=cardianl_columns, drop_first=True)

# %%
X_test = pd.get_dummies(X_test, columns=cardianl_columns, drop_first=True)

# %%
df
# Out:
#              Age    Height      Weight      FCVC       NCP      CH2O  \
# 0      24.443011  1.699998   81.669950  2.000000  2.983297  2.763573
# 1      18.000000  1.560000   57.000000  2.000000  3.000000  2.000000
# 2      18.000000  1.711460   50.165754  1.880534  1.411685  1.910378
# 3      20.952737  1.710730  131.274851  3.000000  3.000000  1.674061
# 4      31.641081  1.914186   93.798055  2.679664  1.971472  1.979848
# ...          ...       ...         ...       ...       ...       ...
# 20753  25.137087  1.766626  114.187096  2.919584  3.000000  2.151809
# 20754  18.000000  1.710000   50.000000  3.000000  4.000000  1.000000
# 20755  20.101026  1.819557  105.580491  2.407817  3.000000  2.000000
# 20756  33.852953  1.700000   83.520113  2.671238  1.971472  2.144838
# 20757  26.680376  1.816547  118.134898  3.000000  3.000000  2.003563
#
#             FAF       TUE  NObeyesdad_encoded  CALC_encoded  CAEC_encoded  \
# ...

# %%
X= df.drop('NObeyesdad_encoded',axis = 1)
y = df.NObeyesdad_encoded

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_test = scaler.transform(X_test)
# Convert the scaled array back to a DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_test = pd.DataFrame(X_test, columns=X.columns)
X_train = X_scaled.copy() # tire 2 code
y_train = y.copy() #tire 2 code
# Split data into train, test, and cv sets
# X_train, X_cv, y_train, y_cv = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y) #tire 2 code removal
# X_test, X_cv, y_test, y_cv = train_test_split(X_cv, y_cv, test_size=0.5, random_state=42, stratify=y_temp)

# %%
# y.value_counts()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from tqdm import tqdm

# %%
a

# %%
# # Define a list of models and their hyperparameter grids
# models = [
#     (Ridge(), {'alpha': [0.1, 1.0, 10.0]}),
#     (Lasso(), {'alpha': [0.01, 0.1, 1.0]}),
#     (ElasticNet(), {'alpha': [0.01, 0.1, 1.0], 'l1_ratio': [0.1, 0.5, 0.9]}),
#     (DecisionTreeRegressor(), {'max_depth': [3, 5, 10]}),
#     (RandomForestRegressor(), {'n_estimators': [50, 100], 'max_depth': [3, 5, 10]}),
#     (GradientBoostingRegressor(), {'n_estimators': [50, 100], 'learning_rate': [0.01, 0.1, 0.2]}),
#     (KNeighborsRegressor(), {'n_neighbors': [3, 5, 7]}),
#     (SVR(), {'C': [0.1, 1.0, 10.0], 'kernel': ['linear', 'rbf']})
# ]

# best_models = []
# for model, params in tqdm(models, desc="Training models"):
#     grid_search = GridSearchCV(model, params, cv=5, scoring='r2',n_jobs=-1)
#     grid_search.fit(X_train, y_train)
#     best_models.append(grid_search.best_estimator_)
#     print(grid_search.best_estimator_)
# # # Evaluate each model on the cross-validation set and calculate the R² score
# # for model in best_models:
#     y_pred = grid_search.predict(X_cv)
    
#     # Replace any negative predictions with 0 and any predictions greater than 6 with 6
#     y_pred = np.where(y_pred < 0, 0, y_pred)
#     y_pred = np.where(y_pred > 6, 6, y_pred)
    
#     r2 = r2_score(y_cv, y_pred)
#     print(f"{model.__class__.__name__} R² score:", r2)
# Out:
# Training models:  12%|███▌                        | 1/8 [00:00<00:02,  3.30it/s]
# Ridge(alpha=0.1)
# Ridge R² score: 0.9383351326440345
# Training models:  25%|███████                     | 2/8 [00:00<00:01,  3.37it/s]
# Lasso(alpha=0.01)
# Lasso R² score: 0.9329242632470569
# Training models:  38%|██████████▌                 | 3/8 [00:01<00:02,  2.48it/s]
# ElasticNet(alpha=0.01, l1_ratio=0.9)
# ElasticNet R² score: 0.9296621174152403
# Training models:  50%|██████████████              | 4/8 [00:01<00:01,  2.04it/s]
# DecisionTreeRegressor(max_depth=10)
# DecisionTreeRegressor R² score: 0.9600389039608819
# Training models:  62%|█████████████████▌          | 5/8 [00:30<00:32, 10.85s/it]
# RandomForestRegressor(max_depth=10)
# RandomForestRegressor R² score: 0.9682237290275888
# Training models:  75%|█████████████████████       | 6/8 [00:51<00:28, 14.01s/it]
# GradientBoostingRegressor(learning_rate=0.2)
# GradientBoostingRegressor R² score: 0.965439404970768
# ...

# %%
# # Define a detailed hyperparameter grid for RandomForestRegressor
# param_grid = {
#     'n_estimators': [100, 200, 300, 400, 500],
#     'max_depth': [None, 10, 20, 30, 40, 50],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4],
#     'max_features': ['auto', 'sqrt', 'log2']
# }
# # Perform GridSearchCV with RandomForestRegressor
# grid_search = GridSearchCV(
#     RandomForestRegressor(random_state=42), 
#     param_grid, 
#     cv=5, 
#     scoring='r2', 
#     n_jobs=-1, 
#     verbose=2
# )
# # Fit the grid search
# grid_search.fit(X_train, y_train)
# # Get the best model
# best_rf = grid_search.best_estimator_
# # Evaluate the best model on the cross-validation set
# y_pred = best_rf.predict(X_cv)
# # Replace any negative predictions with 0 and any predictions greater than 6 with 6
# y_pred = np.where(y_pred < 0, 0, y_pred)
# y_pred = np.where(y_pred > 6, 6, y_pred)
# r2 = r2_score(y_cv, y_pred)
# print(f"Best RandomForestRegressor R² score:", r2)
# print(f"Best parameters: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 810 candidates, totalling 4050 fits
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
# r2 = r2_score(y_cv, y_pred)
# print("R² score:", r2)
# print(f"Best parameters: {grid_search.best_params_}")
# Out:
# R² score: 0.9685924036661305
# Best parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}

# %%
# # Predict on the test set
# y_pred = model.predict(X_train)
# # Round the predictions to get the nearest integer
# # y_pred = np.round(y_pred).astype(int)
# y_pred = np.where(y_pred < 0, 0, y_pred)
# y_pred = np.where(y_pred >6 , 6, y_pred)
# r2 = r2_score(y_train, y_pred)
# print("R² score:", r2)

# %%
# we are now entering to tire 2 code where we will train the model again on whole data set and give prediction to X_test

# %% [markdown]
# <!-- R² score: 0.9685924036661305
# Best parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300} -->

# %%
# y_pred = model.predict(X_test)
# y_pred = np.round(y_pred).astype(int)
# y_pred

# %% [markdown]
# Final Model

# %%
model = RandomForestRegressor(max_depth= 10, max_features='auto', min_samples_leaf=4, min_samples_split=2, n_estimators=300)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_features='auto', min_samples_leaf=4,
#                       n_estimators=300)

# %%
y_pred = best_rf.predict(X_test)
# Replace any negative predictions with 0 and any predictions greater than 6 with 6
y_pred = np.where(y_pred < 0, 0, y_pred)
y_pred = np.where(y_pred > 6, 6, y_pred)
y_pred = np.round(y_pred).astype(int)

# %%
y_pred
# Out:
# array([5, 2, 6, ..., 0, 1, 5])

# %%
# Map numeric predictions back to category labels
label_mapping = {
    0: 'Insufficient_Weight',
    1: 'Normal_Weight',
    2: 'Overweight_Level_I',
    3: 'Overweight_Level_II',
    4: 'Obesity_Type_I',
    5: 'Obesity_Type_II',
    6: 'Obesity_Type_III'
}
y_pred_labels = [label_mapping[int(pred)] for pred in y_pred]

# Create a DataFrame with the predictions
predictions_df = pd.DataFrame({
    'id': X_test_id,
    'NObeyesdad': y_pred_labels
})

# %%
predictions_df
# Out:
#           id           NObeyesdad
# 0      20758      Obesity_Type_II
# 1      20759   Overweight_Level_I
# 2      20760     Obesity_Type_III
# 3      20761       Obesity_Type_I
# 4      20762     Obesity_Type_III
# ...      ...                  ...
# 13835  34593  Overweight_Level_II
# 13836  34594   Overweight_Level_I
# 13837  34595  Insufficient_Weight
# 13838  34596        Normal_Weight
# 13839  34597      Obesity_Type_II
#
# [13840 rows x 2 columns]

# %%
predictions_df.to_csv('submission.csv', index=False)
